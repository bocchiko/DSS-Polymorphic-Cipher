# %%
#CODIGO DEL PROGRAMA FCM HASTA EL FINAL DEL NOTEBOOK
import random
import sympy 

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)
     
def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

def format_message(id, type, payload, psn):
    return (id << 20) | (type << 16) | (payload << 4) | psn

def extract_message_components(message):
    id = (message >> 20) & 0x3F
    type = (message >> 16) & 0xF
    payload = (message >> 4) & 0xFFFFFFFFFFFFFFFF
    psn = message & 0xF
    return id, type, payload, psn

def cipher_message(message, key):
    return message ^ key

def decipher_message(encrypted_message, key):
    return encrypted_message ^ key

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    original_message = original_message[:64]

    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    payload = int.from_bytes(original_message.encode(), byteorder='big')
    formatted_message = format_message(id, 0, payload, psn)

    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    for key in key_table:
        encrypted_message = cipher_message(formatted_message, key)
        decrypted_message = decipher_message(encrypted_message, key)
        id, type, payload, psn = extract_message_components(decrypted_message)
        print("Clave: ", key)
        print("Mensaje Cifrado: ", encrypted_message)
        print("Mensaje Descifrado:")
        print("ID:", id)
        print("Tipo:", type)
        print("Carga útil:", payload.to_bytes((payload.bit_length() + 7) // 8, byteorder='big').decode())
        print("PSN:", psn)

# %%
import random
import sympy 

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        num != (1 << bits - 1) | 1
        if sympy.isprime(num):
            return num

def key_generator():
    p = random.getrandbits(64)
    q = random.getrandbits(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    for i in range(key_number):
        PO = scramble(p, s)
        key = generation(PO, q)
        keys.append(key)
        s = mutation(s, q)
    return keys

def scramble(x, y):
    return (x ^ y) ^ (x >> 1)

def generation(x, y):
    return (x & y) ^ (x << 1)

def mutation(x, y):
    return (x | y) ^ (y >> 1)

def cipher_message(message, key):
    encrypted = []
    for char in message:
        char_code = ord(char)
        encrypted_char_code = char_code ^ key
        encrypted.append(encrypted_char_code)
    return encrypted

def descipher_message(encrypted_message, key):
    decrypted = ""
    for char_code in encrypted_message:
        char_code = char_code ^ key
        decrypted_char = chr(char_code)
        decrypted += decrypted_char
    return decrypted

if __name__ == "__main__":
    cipher_key, descipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, descipher_key, seed)
    original_message = input("Ingrese un mensaje a cifrar: ")
    
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")
    
    print("Tabla de llaves guardada en llaves.txt")

    for key in key_table:
        encrypted_message = cipher_message(original_message, key)
        decrypted_message = descipher_message(encrypted_message, key)
        print("Clave: ", key)
        print("Mensaje Cifrado: ", encrypted_message)
        print("Mensaje Descifrado: ", decrypted_message)

# %%
import random
import sympy

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

# Nuevas funciones de encriptación
def fk1(x, key):
    return fs(x, key)

def fk2(x, key):
    return fg(x, key)

def fk3(x, key):
    return fm(x, key)

def fk4(x, key):
    return fs(x, key)

# Funciones de cifrado y descifrado
def format_message(id, type, payload, psn):
    return (id << 20) | (type << 16) | (payload << 4) | psn

def extract_message_components(message):
    id = (message >> 20) & 0x3F
    type = (message >> 16) & 0xF
    payload = (message >> 4) & 0xFFFFFFFFFFFFFFFF
    psn = message & 0xF
    return id, type, payload, psn

def cipher_message(message, key, psn):
    if psn == 0:
        return fk1(message, key)
    elif psn == 1:
        return fk2(message, key)
    elif psn == 2:
        return fk3(message, key)
    elif psn == 3:
        return fk4(message, key)

def decipher_message(encrypted_message, key, psn):
    if psn == 0:
        return fk1(encrypted_message, key)
    elif psn == 1:
        return fk2(encrypted_message, key)
    elif psn == 2:
        return fk3(encrypted_message, key)
    elif psn == 3:
        return fk4(encrypted_message, key)
    else:
        return encrypted_message

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    # Obtener mensaje desde el usuario
    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    # Asegurarse de que la carga útil tenga un máximo de 64 caracteres
    original_message = original_message[:64]

    # Asignar ID y PSN automáticamente
    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    # Formatear el mensaje
    payload = int.from_bytes(original_message.encode(), byteorder='big')
    formatted_message = format_message(id, 0, payload, psn)

    # Guardar la tabla de llaves en un archivo
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    # Llamar a extract_message_components antes del bucle for
    id, type, payload, psn = extract_message_components(formatted_message)

    # Cifrar y descifrar el mensaje
    for key in key_table:
        encrypted_message = cipher_message(formatted_message, key, psn)
        decrypted_message = decipher_message(encrypted_message, key, psn)
        id, type, payload, psn = extract_message_components(decrypted_message)
        print("Clave: ", key)
        print("Mensaje Cifrado: ", encrypted_message)
        print("Mensaje Descifrado:")
        print("ID:", id)
        print("Tipo:", type)
        print("Carga útil:", payload.to_bytes((payload.bit_length() + 7) // 8, byteorder='big').decode())
        print("PSN:", psn)
# Out:
# Tabla de llaves guardada en llaves.txt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\github\DSS-Polymorphic-Cipher\pruebas.ipynb Cell 3 line 1
#     <a href='vscode-notebook-cell:/d%3A/github/DSS-Polymorphic-Cipher/pruebas.ipynb#W2sZmlsZQ%3D%3D?line=113'>114</a> encrypted_message = cipher_message(formatted_message, key, psn)
#     <a href='vscode-notebook-cell:/d%3A/github/DSS-Polymorphic-Cipher/pruebas.ipynb#W2sZmlsZQ%3D%3D?line=114'>115</a> decrypted_message = decipher_message(encrypted_message, key, psn)
# --> <a href='vscode-notebook-cell:/d%3A/github/DSS-Polymorphic-Cipher/pruebas.ipynb#W2sZmlsZQ%3D%3D?line=115'>116</a> id, type, payload, psn = extract_message_components(decrypted_message)
#     <a href='vscode-notebook-cell:/d%3A/github/DSS-Polymorphic-Cipher/pruebas.ipynb#W2sZmlsZQ%3D%3D?line=116'>117</a> print("Clave: ", key)
# ...

# %%
import random
import sympy

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

# Nuevas funciones de encriptación
def fk1(x, key):
    return fs(x, key)

def fk2(x, key):
    return fg(x, key)

def fk3(x, key):
    return fm(x, key)

def fk4(x, key):
    return fs(x, key)

# Funciones de cifrado
def cipher_message(message, key, psn):
    if psn == 0:
        return fk1(message, key)
    elif psn == 1:
        return fk2(message, key)
    elif psn == 2:
        return fk3(message, key)
    elif psn == 3:
        return fk4(message, key)

def format_message(id, type, payload, psn):
    return (id << 20) | (type << 16) | (payload << 4) | psn

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    # Guardar la tabla de llaves en un archivo
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    # Obtener mensaje desde el usuario
    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    # Asegurarse de que la carga útil tenga un máximo de 64 caracteres
    original_message = original_message[:64]

    # Asignar ID y PSN automáticamente
    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    # Formatear el mensaje
    payload = int.from_bytes(original_message.encode(), byteorder='big')
    formatted_message = format_message(id, 0, payload, psn)

    # Guardar la información en un archivo
    with open("mensaje_encriptado.txt", "w") as file:
        file.write(f"ID: {id}\n")
        file.write(f"Tipo: 0\n")
        file.write(f"Carga Útil: {payload}\n")
        file.write(f"PSN: {psn}\n")

    print("Información encriptada guardada en mensaje_encriptado.txt")

    # Cifrar el mensaje
    encrypted_message = cipher_message(formatted_message, cipher_key, psn)
    print("Mensaje Cifrado:", encrypted_message)
# Out:
# Tabla de llaves guardada en llaves.txt
# Información encriptada guardada en mensaje_encriptado.txt
# Mensaje Cifrado: None

# %%
import random
import sympy

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

# Nuevas funciones de encriptación
def fk1(x, key):
    return fs(x, key)

def fk2(x, key):
    return fg(x, key)

def fk3(x, key):
    return fm(x, key)

def fk4(x, key):
    return fs(x, key)

# Funciones de cifrado y descifrado
def format_message(id, type, payload, psn, encrypted_message):
    return f"ID: {id}\nTipo: {type}\nCarga Útil: {hex(payload)}\nPSN: {psn}\nMensaje Encriptado: {encrypted_message}"

def extract_message_components(message):
    lines = message.strip().split('\n')
    id = int(lines[0].split(': ')[1])
    type = int(lines[1].split(': ')[1])
    payload = int(lines[2].split(': ')[1], 16)
    psn = int(lines[3].split(': ')[1])
    encrypted_message = int(lines[4].split(': ')[1])
    return id, type, payload, psn, encrypted_message

def cipher_message(message, key, psn):
    if psn == 0:
        return fk1(message, key)
    elif psn == 1:
        return fk2(message, key)
    elif psn == 2:
        return fk3(message, key)
    elif psn == 3:
        return fk4(message, key)

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    # Obtener mensaje desde el usuario
    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    # Asegurarse de que la carga útil tenga un máximo de 64 caracteres
    original_message = original_message[:64]

    # Asignar ID y PSN automáticamente
    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    # Formatear el mensaje
    payload = int.from_bytes(original_message.encode(), byteorder='big')

    # Cifrar el mensaje
    encrypted_message = cipher_message(payload, key_table[0], psn)

    # Crear un mensaje formateado con todos los componentes
    formatted_message = format_message(id, 0, payload, psn, encrypted_message)

    # Guardar la tabla de llaves en un archivo
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    # Guardar el mensaje encriptado en un archivo
    with open("mensaje_encriptado.txt", "w") as file:
        file.write(formatted_message)
        print("Mensaje encriptado guardado en mensaje_encriptado.txt")
# Out:
# Tabla de llaves guardada en llaves.txt
# Mensaje encriptado guardado en mensaje_encriptado.txt

# %%
import random
import sympy

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

# Nuevas funciones de encriptación
def fk1(x, key):
    return fs(x, key)

def fk2(x, key):
    return fg(x, key)

def fk3(x, key):
    return fm(x, key)

def fk4(x, key):
    return fs(x, key)

# Funciones de cifrado y descifrado
def format_message(id, type, payload, psn, encrypted_message):
    return f"ID: {id}\nTipo: {type}\nCarga Útil: {hex(payload)}\nPSN: {psn}\nMensaje Encriptado: {encrypted_message}"

def extract_message_components(message):
    lines = message.strip().split('\n')
    id = int(lines[0].split(': ')[1])
    type = int(lines[1].split(': ')[1])
    payload = int(lines[2].split(': ')[1], 16)
    psn = int(lines[3].split(': ')[1])
    encrypted_message = int(lines[4].split(': ')[1])
    return id, type, payload, psn, encrypted_message

def cipher_message(message, key, psn):
    encrypted_message = message
    for i in range(4):  # Procesar cada bit de PSN
        bit = (psn >> i) & 1
        if bit == 0:
            encrypted_message = fk1(encrypted_message, key)
        elif bit == 1:
            encrypted_message = fk2(encrypted_message, key)
        elif bit == 2:
            encrypted_message = fk3(encrypted_message, key)
        elif bit == 3:
            encrypted_message = fk4(encrypted_message, key)
    return encrypted_message

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    # Obtener mensaje desde el usuario
    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    # Asegurarse de que la carga útil tenga un máximo de 64 caracteres
    original_message = original_message[:64]

    # Asignar ID y PSN automáticamente
    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    # Formatear el mensaje
    payload = int.from_bytes(original_message.encode(), byteorder='big')

    # Cifrar el mensaje
    encrypted_message = cipher_message(payload, key_table[0], psn)

    # Crear un mensaje formateado con todos los componentes
    formatted_message = format_message(id, 0, payload, psn, encrypted_message)

    # Guardar la tabla de llaves en un archivo
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    # Guardar el mensaje encriptado en un archivo
    with open("mensaje_encriptado.txt", "w") as file:
        file.write(formatted_message)
        print("Mensaje encriptado guardado en mensaje_encriptado.txt")
# Out:
# Tabla de llaves guardada en llaves.txt
# Mensaje encriptado guardado en mensaje_encriptado.txt

# %%
import random
import sympy
import os

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

# Nuevas funciones de encriptación
def fk1(x, key):
    return fs(x, key)

def fk2(x, key):
    return fg(x, key)

def fk3(x, key):
    return fm(x, key)

def fk4(x, key):
    return fs(x, key)

# Funciones de cifrado y descifrado
def format_message(id, type, payload, psn, encrypted_message):
    return f"ID: {id}\nTipo: {type}\nCarga Útil: {hex(payload)}\nPSN: {psn}\nMensaje Encriptado: {encrypted_message}"

def extract_message_components(message):
    lines = message.strip().split('\n')
    id = int(lines[0].split(': ')[1])
    type = int(lines[1].split(': ')[1])
    payload = int(lines[2].split(': ')[1], 16)
    psn = int(lines[3].split(': ')[1])
    encrypted_message = int(lines[4].split(': ')[1])
    return id, type, payload, psn, encrypted_message

def cipher_message(message, key, psn):
    encrypted_message = message
    psn_bits = psn.bit_length()
    for i in range(psn_bits):
        bit = (psn >> i) & 1
        if bit == 0:
            encrypted_message = fk1(encrypted_message, key)
        elif bit == 1:
            encrypted_message = fk2(encrypted_message, key)
        elif bit == 2:
            encrypted_message = fk3(encrypted_message, key)
        elif bit == 3:
            encrypted_message = fk4(encrypted_message, key)
        else:
            raise ValueError("Valor de PSN no válido")
    return encrypted_message

def divide_message(message):
    binary_message = ''.join(format(ord(char), '08b') for char in message)
    parts = []
    while len(binary_message) % 4 != 0:
        binary_message = '0' + binary_message
    for i in range(0, len(binary_message), 4):
        parts.append(binary_message[i:i+4])
    return parts

def get_last_psn(filename):
    with open(filename, "r") as file:
        lines = file.readlines()
        if lines:
            last_line = lines[-1]
            last_psn = int(last_line.split(': ')[1])
            return last_psn
        else:
            return 0

def select_psn_for_message(previous_psn, bits):
    # Suma un valor aleatorio y asegúrate de que el resultado tenga la cantidad correcta de bits
    random_bits = random.getrandbits(bits)
    new_psn = (previous_psn + random_bits) & ((1 << bits) - 1)
    return new_psn

def save_message(filename, formatted_message):
    # Guardar el mensaje encriptado en un archivo (reemplazando el archivo si ya existe)
    with open(filename, "w") as file:
        file.write(formatted_message)

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    # Obtener mensaje desde el usuario
    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    # Asegurarse de que la carga útil tenga un máximo de 64 caracteres
    original_message = original_message[:64]

    # Obtener el archivo de mensajes encriptados si existe
    message_file = "mensaje_encriptado.txt"

    # Dividir el mensaje en partes y llenar la parte más significativa con ceros
    message_parts = divide_message(original_message)

    # Obtener el último PSN del archivo si existe, de lo contrario, usar 0
    last_psn = get_last_psn(message_file) if os.path.isfile(message_file) else 0

    # Seleccionar el PSN para el nuevo mensaje
    psn = select_psn_for_message(last_psn, 4)  # 4 bits para el PSN

    # Asignar un ID aleatorio para el nuevo mensaje
    id = random.randint(0, 0x3F)  # 6 bits

    # Cifrar cada parte y construir el mensaje cifrado
    encrypted_message = 0
    for part in message_parts:
        encrypted_part = cipher_message(int(part, 2), key_table[0], psn)
        encrypted_message = (encrypted_message << 4) | encrypted_part

    # Crear un mensaje formateado con todos los componentes
    formatted_message = format_message(id, 0, int(original_message.encode().hex(), 16), psn, encrypted_message)

    # Guardar el mensaje encriptado en un archivo (reemplazando el archivo si ya existe)
    save_message(message_file, formatted_message)

    print("Mensaje encriptado guardado en mensaje_encriptado.txt")

    # Guardar la tabla de llaves en un archivo
    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

# %%
import random
import sympy 

# Funciones de generación de llaves
def fs(x, y):
    return (x ^ y) ^ (x >> 1)

def fg(x, y):
    return (x & y) ^ (x << 1)

def fm(x, y):
    return (x | y) ^ (y >> 1)

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        if sympy.isprime(num):
            return num

def key_generator():
    p = generate_prime(64)
    q = generate_prime(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    psn = 0  # Inicializa PSN en 0
    for i in range(key_number):
        PO = fs(p, s)
        key = fg(PO, q)
        keys.append(key)
        s = fm(s, q)
        psn = (psn + 1) % 16  # Actualiza PSN
    return keys

def format_message(id, type, payload, psn):
    return (id << 20) | (type << 16) | (payload << 4) | psn

def extract_message_components(message):
    id = (message >> 20) & 0x3F
    type = (message >> 16) & 0xF
    payload = (message >> 4) & 0xFFFFFFFFFFFFFFFF
    psn = message & 0xF
    return id, type, payload, psn

def cipher_message(message, key):
    return message ^ key

def decipher_message(encrypted_message, key):
    return encrypted_message ^ key

if __name__ == "__main__":
    cipher_key, decipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, decipher_key, seed)

    original_message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")

    original_message = original_message[:64]

    id = random.randint(0, 0x3F)  # 6 bits
    psn = random.randint(0, 0xF)   # 4 bits

    payload = int.from_bytes(original_message.encode(), byteorder='big')
    formatted_message = format_message(id, 0, payload, psn)

    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    for key in key_table:
        encrypted_message = cipher_message(formatted_message, key)
        decrypted_message = decipher_message(encrypted_message, key)
        id, type, payload, psn = extract_message_components(decrypted_message)
        print("Clave: ", key)
        print("Mensaje Cifrado: ", encrypted_message)
        print("Mensaje Descifrado:")
        print("ID:", id)
        print("Tipo:", type)
        print("Carga útil:", payload.to_bytes((payload.bit_length() + 7) // 8, byteorder='big').decode())
        print("PSN:", psn)
# Out:
# Tabla de llaves guardada en llaves.txt
# Clave:  33357857774140287504
# Mensaje Cifrado:  33356328588763495584
# Mensaje Descifrado:
# ID: 61
# Tipo: 6
# Carga útil: yos}ak
# PSN: 0
# Clave:  24092679211475759891
# Mensaje Cifrado:  24093680690092402083
# Mensaje Descifrado:
# ID: 61
# Tipo: 6
# Carga útil: yos}ak
# PSN: 0
# Clave:  19464248113000212371
# Mensaje Cifrado:  19462710956841759011
# Mensaje Descifrado:
# ID: 61
# Tipo: 6
# Carga útil: yos}ak
# PSN: 0
# Clave:  24092679211475759891
# Mensaje Cifrado:  24093680690092402083
# Mensaje Descifrado:
# ID: 61
# Tipo: 6
# Carga útil: yos}ak
# PSN: 0
# Clave:  19464248113000212371
# Mensaje Cifrado:  19462710956841759011
# Mensaje Descifrado:
# ID: 61
# Tipo: 6
# Carga útil: yos}ak
# PSN: 0

# %%
import random
import sympy 

def generate_prime(bits):
    while True:
        num = random.getrandbits(bits)
        num != (1 << bits - 1) | 1
        if sympy.isprime(num):
            return num

def key_generator():
    p = random.getrandbits(64)
    q = random.getrandbits(64)
    s = random.getrandbits(64)
    return p, q, s

def key_table_generator(key_number, p, q, s):
    keys = []
    for i in range(key_number):
        PO = scramble(p, s)
        key = generation(PO, q)
        keys.append(key)
        s = mutation(s, q)
    return keys

def scramble(x, y):
    return (x ^ y) ^ (x >> 1)

def generation(x, y):
    return (x & y) ^ (x << 1)

def mutation(x, y):
    return (x | y) ^ (y >> 1)

def cipher_message(message, key):
    encrypted = []
    for char in message:
        char_code = ord(char)
        encrypted_char_code = char_code ^ key
        encrypted.append(encrypted_char_code)
    return encrypted

def descipher_message(encrypted_message, key):
    decrypted = ""
    for char_code in encrypted_message:
        char_code = char_code ^ key
        decrypted_char = chr(char_code)
        decrypted += decrypted_char
    return decrypted

if __name__ == "__main__":
    cipher_key, descipher_key, seed = key_generator()
    key_number = 5
    key_table = key_table_generator(key_number, cipher_key, descipher_key, seed)
    original_message = input("Ingrese un mensaje a cifrar: ")

    with open("llaves.txt", "w") as file:
        for i, key in enumerate(key_table, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en llaves.txt")

    for key in key_table:
        encrypted_message = cipher_message(original_message, key)
        decrypted_message = descipher_message(encrypted_message, key)
        print("Clave: ", key)
        print("Mensaje Cifrado: ", encrypted_message)
        print("Mensaje Descifrado: ", decrypted_message)
# Out:
# Tabla de llaves guardada en llaves.txt
# Clave:  19819664213788071418
# Mensaje Cifrado:  [19819664213788071312, 19819664213788071317, 19819664213788071305, 19819664213788071315, 19819664213788071323, 19819664213788071305]
# Mensaje Descifrado:  josias
# Clave:  1948710464739093230
# Mensaje Cifrado:  [1948710464739093124, 1948710464739093121, 1948710464739093149, 1948710464739093127, 1948710464739093135, 1948710464739093149]
# Mensaje Descifrado:  josias
# Clave:  5984057914528960252
# Mensaje Cifrado:  [5984057914528960150, 5984057914528960147, 5984057914528960143, 5984057914528960149, 5984057914528960157, 5984057914528960143]
# Mensaje Descifrado:  josias
# Clave:  1948710464739093230
# Mensaje Cifrado:  [1948710464739093124, 1948710464739093121, 1948710464739093149, 1948710464739093127, 1948710464739093135, 1948710464739093149]
# Mensaje Descifrado:  josias
# Clave:  5984057914528960252
# ...

# %%
# Función de cifrado
def encrypt_message(message, key):
    x = int.from_bytes(message.encode(), 'big')  # Convertir el mensaje a un entero
    y = key  # La clave secreta
    scrambled = scramble(x, y)
    generated = generation(scrambled, y)
    mutated = mutation(generated, y)
    return mutated

# Función de descifrado
def decrypt_message(ciphertext, key):
    y = key  # La misma clave secreta utilizada para cifrar
    generated_inverse = mutation(ciphertext, y)
    scrambled_inverse = generation(generated_inverse, y)
    x = scramble(scrambled_inverse, y)
    return x.to_bytes((x.bit_length() + 7) // 8, 'big').decode()

# Mensaje original y clave
mensaje_original = "Hola, este es un mensaje secreto."
clave_secreta = 12345

# Cifrar el mensaje
mensaje_cifrado = encrypt_message(mensaje_original, clave_secreta)
print("Mensaje cifrado:", mensaje_cifrado)

# Descifrar el mensaje
mensaje_descifrado = decrypt_message(mensaje_cifrado, clave_secreta)
print("Mensaje descifrado:", mensaje_descifrado)
# Out:
# Mensaje cifrado: 25091469810053387022905968706005440317142563258462586027887562049840983666649381
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\josias\Documents\GitHub\DSS-Polymorphic-Cipher\pruebas.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/josias/Documents/GitHub/DSS-Polymorphic-Cipher/pruebas.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> print("Mensaje cifrado:", mensaje_cifrado)
#      <a href='vscode-notebook-cell:/c%3A/Users/josias/Documents/GitHub/DSS-Polymorphic-Cipher/pruebas.ipynb#X12sZmlsZQ%3D%3D?line=25'>26</a> # Descifrar el mensaje
# ---> <a href='vscode-notebook-cell:/c%3A/Users/josias/Documents/GitHub/DSS-Polymorphic-Cipher/pruebas.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> mensaje_descifrado = decrypt_message(mensaje_cifrado, clave_secreta)
# ...

# %%
#CODIGO DE PROGRAMA FCM CREADO POR YOSIAK

from functions import methods
import utils


def encrypt(message, keys, psn):
    encrypted_message = []
    key_index = 0
    
    for char in message:
        char_code = ord(char)
        key = keys[key_index]
        encrypted_char_code = methods.apply_reversible_functions(char_code, key, psn)
        encrypted_message.append(encrypted_char_code)
        
        key_index += 1
        if key_index >= len(keys):
            key_index = 0
    
    return encrypted_message


def format_message(id, type, payload, psn):
    return f"{id}\n{type}\n{payload}\n{psn}"

# Guardar el mensaje encriptado en un archivo
def save_message(filename, formatted_message):
    with open(filename, "w") as file:
        file.write(formatted_message)
# Example usage
if __name__ == "__main__":
    P , Q , S = utils.pqs_generator()
    
    key_number = input("Ingrese numero de llaves a generar: ")
    #keys = [generate_key(P , Q , S + i) for i in range(int(key_number))]
    keys = utils.key_table_generator(P,Q,S,int(key_number))
    message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")
    psn = utils.select_psn(message)  # Select PSN based on message
    
    encrypted_message = encrypt(message, keys, psn)

    ft_message = format_message('{:06d}'.format(1), '{:04d}'.format(0), [P, Q, S, int(key_number)], 'N\A')
    save_message('results/FCM_Server_result.txt', ft_message)
    
    # Guardar la tabla de llaves en un archivo
    with open("results/FCM_llaves.txt", "w") as file:
        for i, key in enumerate(keys, 1):
            file.write(f"Numero de llave {i}: {key}\n")

    print("Tabla de llaves guardada en results/FCM_Server_result.txt")
    print("Mensaje encriptado guardado en results/FCM_Server_result.txt")

# %%
#CODIGO DE PROGRAMA RM CREADO POR YOSIAK

from functions import methods
import utils

# Encryption function
def encrypt(message, keys, psn):
    encrypted_message = []
    key_index = 0
    
    for char in message:
        char_code = ord(char)
        key = keys[key_index]
        encrypted_char_code = methods.apply_reversible_functions(char_code, key, psn)
        encrypted_message.append(encrypted_char_code)
        
        key_index += 1
        if key_index >= len(keys):
            key_index = 0
    
    return encrypted_message

# Decryption function
def decrypt(encrypted_message, keys, psn):
    decrypted_message = []
    key_index = 0
    
    for char_code in encrypted_message:
        key = keys[key_index]
        decrypted_char_code = methods.apply_reversible_functions(char_code, key, psn)
         # Ensure the decrypted character code is within the valid Unicode range
        decrypted_char_code %= 0x110000
        decrypted_message.append(chr(decrypted_char_code))
        
        key_index += 1
        if key_index >= len(keys):
            key_index = 0
    
    return ''.join(decrypted_message)

def format_message(id, type, payload, psn):
    return f"{id}\n{type}\n{payload}\n{psn}"

# Guardar el mensaje encriptado en un archivo
def save_message(filename, formatted_message):
    with open(filename, "w") as file:
        file.write(formatted_message)
# Example usage
if __name__ == "__main__":
    
    P , Q , S = utils.pqs_generator()
    
    key_number = input("Ingrese numero de llaves a generar: ")
    #keys = [generate_key(P , Q , S + i) for i in range(int(key_number))]
    keys = utils.key_table_generator(P,Q,S,int(key_number))
    message = input("Ingrese el mensaje a cifrar (máximo 64 caracteres): ")
    psn = utils.select_psn(message)  # Select PSN based on message
    
    encrypted_message = encrypt(message, keys, psn)
    decrypted_message = decrypt(encrypted_message, keys, psn)

    ft_message = format_message('{:06d}'.format(1), '{:04d}'.format(1), encrypted_message , psn)
    save_message('results/RM_Server_result.txt', ft_message)
    
    # Guardar la tabla de llaves en un archivo
    with open("results/RM_llaves.txt", "w") as file:
        for i, key in enumerate(keys, 1):
            file.write(f"Numero de llave {i}: {key}\n")
    
    print("Client Encrypted Message:", encrypted_message)
    print("Decrypted Server Message:", decrypted_message)
